# %% [markdown]
# # EXPERIMENTAL
# Sharded Whisper with NxD

# %%
# %%writefile compile.py
import os
#os.environ['XLA_USE_BF16']='1'
import types
import torch
import argparse
import torch_neuronx
import transformers
from datasets import load_dataset
from transformers import WhisperProcessor, WhisperForConditionalGeneration

import neuronx_distributed
import neuronx_distributed.parallel_layers.utils as neuronx_dist_utils
from transformers.models.whisper.modeling_whisper import WhisperAttention

from torch import nn
from neuronx_distributed.parallel_layers import layers, parallel_state
from functools import partial

conf = {}
conf['suffix'] = 'tiny' # 'large-v3'
conf['model_id'] = f"openai/whisper-{conf['suffix']}"
conf['tp_degree'] = 2
conf['embed_dim_per_head'] = 64
conf['max_dec_len'] = 64

def wrap_model():
    global conf    
    model = WhisperForConditionalGeneration.from_pretrained(conf['model_id'], torchscript=True)

    # Here we build a model with tensor-parallel layers.
    class NxDWhisperAttention(WhisperAttention):
        def __init__(self, embed_dim, num_heads, dropout, is_decoder,bias,is_causal,config):
            super().__init__(embed_dim, num_heads, dropout, is_decoder,bias,is_causal,config)
            self.q_proj = layers.ColumnParallelLinear(embed_dim, embed_dim, bias=bias, gather_output=False)
            self.k_proj = layers.ColumnParallelLinear(embed_dim, embed_dim, bias=False, gather_output=False)
            self.v_proj = layers.ColumnParallelLinear(embed_dim, embed_dim, bias=bias, gather_output=False)
            
            self.out_proj = layers.RowParallelLinear(embed_dim, embed_dim, bias=bias, input_is_parallel=True)

            # self.num_heads = neuronx_dist_utils.divide(num_heads, parallel_state.get_tensor_model_parallel_size())
            # self.embed_dim = neuronx_dist_utils.divide(embed_dim, parallel_state.get_tensor_model_parallel_size())
            # self.head_dim = neuronx_dist_utils.divide(self.embed_dim, self.num_heads)
            # self.scaling = self.head_dim**-0.5
            self.heads_pad = get_pad_size(config.d_model, parallel_state.get_tensor_model_parallel_size())
            
            self.num_heads = neuronx_dist_utils.divide(
               num_heads + self.heads_pad,
               parallel_state.get_tensor_model_parallel_size())
            
            self.embed_dim = neuronx_dist_utils.divide(
               embed_dim + (conf['embed_dim_per_head'] * self.heads_pad),
               parallel_state.get_tensor_model_parallel_size())
            
            self.head_dim = neuronx_dist_utils.divide(self.embed_dim, self.num_heads)
            self.scaling = self.head_dim**-0.5

    for layer in model.model.encoder.layers:
        l = layer.self_attn
        layer.self_attn = NxDWhisperAttention(l.embed_dim, l.num_heads, l.dropout, l.is_decoder, True, l.is_causal, l.config)

    for layer in model.model.decoder.layers:
        l = layer.self_attn
        layer.self_attn = NxDWhisperAttention(l.embed_dim, l.num_heads, l.dropout, l.is_decoder, True, l.is_causal, l.config)
        l = layer.encoder_attn
        layer.encoder_attn = NxDWhisperAttention(l.embed_dim, l.num_heads, l.dropout, l.is_decoder, True, l.is_causal, l.config)

    if not hasattr(model.model.encoder, 'forward_'): model.model.encoder.forward_ = model.model.encoder.forward
    def enc_f(self, input_features, attention_mask, **kwargs):        
        return self.forward_(input_features, attention_mask, return_dict=False)
    model.model.encoder.forward = types.MethodType(enc_f, model.model.encoder)    

    if not hasattr(model.model.decoder, 'forward_'): model.model.decoder.forward_ = model.model.decoder.forward
    def dec_f(self, input_ids, encoder_hidden_states, **kwargs):
        return self.forward_(input_ids=input_ids, encoder_hidden_states=encoder_hidden_states, use_cache=False)[0]
    model.model.decoder.forward = types.MethodType(dec_f, model.model.decoder)

    neuronx_distributed.parallel_layers.load(f"whisper-{conf['suffix']}.pt", model, sharded=False)
    
    return model.model
    
def get_model_encoder():
    global conf
    model = wrap_model().encoder
    if get_pad_size(model.config.d_model, conf['tp_degree']) > 0:
        print("Padding Encoder...")
        model = neuronx_distributed.parallel_layers.pad.pad_model(model, tp_degree=conf['tp_degree'], n_heads=model.config.encoder_attention_heads)
    return model, {}

def get_model_decoder():
    global conf
    model = wrap_model().decoder
    if get_pad_size(model.config.d_model, conf['tp_degree']) > 0:
        print("Padding Decoder...")
        model = neuronx_distributed.parallel_layers.pad.pad_model(model, tp_degree=conf['tp_degree'], n_heads=model.config.decoder_attention_heads)
    return model, {}

def get_pad_size(n_heads, tp_degree):
    heads_pad = 0
    # find the optimal padding considering at most 32 cores
    for i in range(32): 
        if (n_heads+i) % tp_degree == 0:
            heads_pad = i
            break
    print(f"Heads pad: {heads_pad}\nTP degree: {tp_degree}")    
    return heads_pad    

if __name__=='__main__':
    # 'attention_mask', 'input_features'    
    if not os.path.isfile(f"whisper-{conf['suffix']}.pt"):
        print(f"Saving the original weights: {conf['model_id']}...")
        model = WhisperForConditionalGeneration.from_pretrained(conf['model_id'], torchscript=True)
        torch.save({"model":model.state_dict()}, f"whisper-{conf['suffix']}.pt")

    print(f"Exporting encoder: whisper-{conf['suffix']}")    
    
    if conf['suffix'] == "tiny":
        dim_enc,dim_dec=80,384
    elif conf['suffix'] == "large-v3":
        dim_enc,dim_dec=128,1280
        
    inp = (torch.zeros([1, dim_enc, 3000], dtype=torch.float32), torch.zeros([1, dim_enc], dtype=torch.int64))
    model = neuronx_distributed.trace.parallel_model_trace(
        get_model_encoder, 
        inp, 
        tp_degree=conf['tp_degree'],
        compiler_args='--model-type=transformer --enable-saturate-infinity --auto-cast=all',
        compiler_workdir='./enc_dir',
        inline_weights_to_neff=False,
        max_parallel_compilations=max(4, conf['tp_degree'])
    )
    neuronx_distributed.trace.parallel_model_save(model, f"tp_model_enc_{conf['suffix']}_{conf['tp_degree']}")
        
    print(f"Exporting decoder: whisper-{conf['suffix']}")
    inp = (torch.zeros([1, conf['max_dec_len']], dtype=torch.int64), torch.zeros([1, 1500, dim_dec], dtype=torch.float32))    
    model = neuronx_distributed.trace.parallel_model_trace(
        get_model_decoder, 
        inp, 
        tp_degree=conf['tp_degree'],
        compiler_args='--model-type=transformer --enable-saturate-infinity  --auto-cast=all',
        compiler_workdir='./dec_dir',
        inline_weights_to_neff=True,
        max_parallel_compilations=max(4, conf['tp_degree'])
    )
    neuronx_distributed.trace.parallel_model_save(model, f"tp_model_dec_{conf['suffix']}_{conf['tp_degree']}")
# Out:
# Overwriting compile.py

# %%
# %%bash
#
# rm -rf tp_model_enc_* tp_model_dec_*
#
# kill -9 $(ps aux|grep multiprocessing|awk '{print $2}')
#
# python3 compile.py
# Out:
# bash: line 4: kill: (104759) - No such process
# Exporting encoder: whisper-tiny
# Some weights of WhisperForConditionalGeneration were not initialized from the model checkpoint at openai/whisper-tiny and are newly initialized: ['proj_out.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# > initializing tensor model parallel with size 2
# > initializing pipeline model parallel with size 1
# > initializing data parallel with size 1
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# [2024-05-01 16:43:30.090: I neuronx_distributed/parallel_layers/checkpointing.py:148] `load` kwarg `model` is deprecated, please use `model_or_optimizer` instead as we are supporting to use `load` with optimizer as well
# [2024-05-01 16:43:30.090: I neuronx_distributed/parallel_layers/checkpointing.py:161] loading checkpoint from whisper-tiny.pt
# /opt/conda/lib/python3.10/site-packages/torch_neuronx/xla_impl/hlo_conversion.py:143: UserWarning: Received an input tensor that was unused. Tensor will be ignored. (index=1, shape=torch.Size([1, 80]), dtype=torch.int64)
#   warnings.warn(
# 2024-05-01 16:43:39.000902:  107413  INFO ||NEURON_CACHE||: Compile cache path: /var/tmp/neuron-compile-cache
# 2024-05-01 16:43:39.000904:  107413  INFO ||NEURON_CC_WRAPPER||: Using a cached neff at /var/tmp/neuron-compile-cache/neuronxcc-2.13.68.0+6dfecc895/MODULE_9921017747686325983+d41d8cd9/model.neff. Exiting with a successfully compiled graph.
# 2024-05-01 16:43:40.000112:  107420  INFO ||NEURON_CACHE||: Compile cache path: /var/tmp/neuron-compile-cache
# 2024-05-01 16:43:40.000113:  107420  INFO ||NEURON_CC_WRAPPER||: Using a cached neff at /var/tmp/neuron-compile-cache/neuronxcc-2.13.68.0+6dfecc895/MODULE_16942971074878409330+d41d8cd9/model.neff. Exiting with a successfully compiled graph.
# 2024-05-01 16:43:40.000310:  107426  INFO ||NEURON_CACHE||: Compile cache path: /var/tmp/neuron-compile-cache
# 2024-05-01 16:43:40.000311:  107426  INFO ||NEURON_CC_WRAPPER||: Using a cached neff at /var/tmp/neuron-compile-cache/neuronxcc-2.13.68.0+6dfecc895/MODULE_1703642196029355321+d41d8cd9/model.neff. Exiting with a successfully compiled graph.
# 2024-05-01 16:43:40.000506:  107435  INFO ||NEURON_CACHE||: Compile cache path: /var/tmp/neuron-compile-cache
# 2024-05-01 16:43:40.000507:  107435  INFO ||NEURON_CC_WRAPPER||: Using a cached neff at /var/tmp/neuron-compile-cache/neuronxcc-2.13.68.0+6dfecc895/MODULE_9412458797141338827+d41d8cd9/model.neff. Exiting with a successfully compiled graph.
# 2024-05-01 16:43:40.000700:  107441  INFO ||NEURON_CACHE||: Compile cache path: /var/tmp/neuron-compile-cache
# 2024-05-01 16:43:40.000701:  107441  INFO ||NEURON_CC_WRAPPER||: Using a cached neff at /var/tmp/neuron-compile-cache/neuronxcc-2.13.68.0+6dfecc895/MODULE_766892254041788032+d41d8cd9/model.neff. Exiting with a successfully compiled graph.
# 2024-05-01 16:43:40.000889:  107450  INFO ||NEURON_CACHE||: Compile cache path: /var/tmp/neuron-compile-cache
# 2024-05-01 16:43:40.000890:  107450  INFO ||NEURON_CC_WRAPPER||: Using a cached neff at /var/tmp/neuron-compile-cache/neuronxcc-2.13.68.0+6dfecc895/MODULE_9279805290075389978+d41d8cd9/model.neff. Exiting with a successfully compiled graph.
# 2024-05-01 16:43:41.000080:  107462  INFO ||NEURON_CACHE||: Compile cache path: /var/tmp/neuron-compile-cache
# 2024-05-01 16:43:41.000081:  107462  INFO ||NEURON_CC_WRAPPER||: Using a cached neff at /var/tmp/neuron-compile-cache/neuronxcc-2.13.68.0+6dfecc895/MODULE_5923153053738227728+d41d8cd9/model.neff. Exiting with a successfully compiled graph.
# 2024-05-01 16:43:41.000268:  107477  INFO ||NEURON_CACHE||: Compile cache path: /var/tmp/neuron-compile-cache
# 2024-05-01 16:43:41.000270:  107477  INFO ||NEURON_CC_WRAPPER||: Using a cached neff at /var/tmp/neuron-compile-cache/neuronxcc-2.13.68.0+6dfecc895/MODULE_6628613090798822721+d41d8cd9/model.neff. Exiting with a successfully compiled graph.
# 2024-05-01 16:43:41.000461:  107483  INFO ||NEURON_CACHE||: Compile cache path: /var/tmp/neuron-compile-cache
# 2024-05-01 16:43:41.000462:  107483  INFO ||NEURON_CC_WRAPPER||: Using a cached neff at /var/tmp/neuron-compile-cache/neuronxcc-2.13.68.0+6dfecc895/MODULE_16715834710487042195+d41d8cd9/model.neff. Exiting with a successfully compiled graph.
# 2024-05-01 16:43:41.000647:  107489  INFO ||NEURON_CACHE||: Compile cache path: /var/tmp/neuron-compile-cache
# 2024-05-01 16:43:41.000648:  107489  INFO ||NEURON_CC_WRAPPER||: Using a cached neff at /var/tmp/neuron-compile-cache/neuronxcc-2.13.68.0+6dfecc895/MODULE_6664028047681252389+d41d8cd9/model.neff. Exiting with a successfully compiled graph.
# Some weights of WhisperForConditionalGeneration were not initialized from the model checkpoint at openai/whisper-tiny and are newly initialized: ['proj_out.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# [2024-05-01 16:43:42.508: I neuronx_distributed/parallel_layers/checkpointing.py:148] `load` kwarg `model` is deprecated, please use `model_or_optimizer` instead as we are supporting to use `load` with optimizer as well
# 2024-05-01T16:43:42Z Running DoNothing
# 2024-05-01T16:43:42Z DoNothing finished after 0.000 seconds
# 2024-05-01T16:43:42Z Running AliasDependencyInduction
# 2024-05-01T16:43:42Z AliasDependencyInduction finished after 0.002 seconds
# 2024-05-01T16:43:42Z Running CanonicalizeIR
# 2024-05-01T16:43:42Z CanonicalizeIR finished after 0.005 seconds
# 2024-05-01T16:43:42Z Running LegalizeCCOpLayout
# 2024-05-01T16:43:42Z LegalizeCCOpLayout finished after 0.007 seconds
# 2024-05-01T16:43:42Z Running ResolveComplicatePredicates
# 2024-05-01T16:43:42Z ResolveComplicatePredicates finished after 0.005 seconds
# 2024-05-01T16:43:42Z Running AffinePredicateResolution
# 2024-05-01T16:43:42Z AffinePredicateResolution finished after 0.005 seconds
# 2024-05-01T16:43:42Z Running EliminateDivs
# 2024-05-01T16:43:42Z EliminateDivs finished after 0.005 seconds
# 2024-05-01T16:43:42Z Running PerfectLoopNest
# 2024-05-01T16:43:42Z PerfectLoopNest finished after 0.005 seconds
# 2024-05-01T16:43:42Z Running Simplifier
# 2024-05-01T16:43:42Z Simplifier finished after 0.020 seconds
# 2024-05-01T16:43:42Z Running GenericAccessSimplifier
# 2024-05-01T16:43:42Z GenericAccessSimplifier finished after 0.005 seconds
# 2024-05-01T16:43:42Z Running TCTransform
# 2024-05-01T16:43:42Z TCTransform finished after 0.005 seconds
# 2024-05-01T16:43:42Z Running CommuteConcat
# 2024-05-01T16:43:42Z CommuteConcat finished after 0.005 seconds
# 2024-05-01T16:43:42Z Running LowerTensorOp
# 2024-05-01T16:43:42Z LowerTensorOp finished after 0.047 seconds
# 2024-05-01T16:43:42Z Running ExpandBatchNorm
# 2024-05-01T16:43:42Z ExpandBatchNorm finished after 0.012 seconds
# 2024-05-01T16:43:42Z Running TCTransform
# 2024-05-01T16:43:42Z TCTransform finished after 0.017 seconds
# 2024-05-01T16:43:42Z Running EliminateDivs
# 2024-05-01T16:43:42Z EliminateDivs finished after 0.010 seconds
# 2024-05-01T16:43:42Z Running GenericAccessSimplifier
# 2024-05-01T16:43:43Z GenericAccessSimplifier finished after 0.011 seconds
# 2024-05-01T16:43:43Z Running CanonicalizeIR
# 2024-05-01T16:43:43Z CanonicalizeIR finished after 0.009 seconds
# 2024-05-01T16:43:43Z Running TensorOpFusion
# 2024-05-01T16:43:43Z TensorOpFusion finished after 0.013 seconds
# 2024-05-01T16:43:43Z Running TensorOpTransform
# 2024-05-01T16:43:43Z TensorOpTransform finished after 0.038 seconds
# 2024-05-01T16:43:43Z Running LateLowerTensorOp
# 2024-05-01T16:43:43Z LateLowerTensorOp finished after 0.023 seconds
# 2024-05-01T16:43:43Z Running MemcpyElimination
# /opt/conda/lib/python3.10/site-packages/torch_neuronx/xla_impl/hlo_conversion.py:143: UserWarning: Received an input tensor that was unused. Tensor will be ignored. (index=1, shape=torch.Size([1, 80]), dtype=torch.int64)
#   warnings.warn(
# 2024-05-01T16:43:43Z MemcpyElimination finished after 0.549 seconds
# 2024-05-01T16:43:43Z Running LoopFusion
# 2024-05-01T16:43:43Z LoopFusion finished after 0.177 seconds
# 2024-05-01T16:43:43Z Running Simplifier
# 2024-05-01T16:43:43Z Simplifier finished after 0.014 seconds
# 2024-05-01T16:43:43Z Running Delinearization
# 2024-05-01T16:43:43Z Delinearization finished after 0.022 seconds
# 2024-05-01T16:43:43Z Running AliasDependencyElimination
# 2024-05-01T16:43:43Z AliasDependencyElimination finished after 0.006 seconds
# 2024-05-01T16:43:43Z Running DeadStoreElimination
# 2024-05-01T16:43:44Z DeadStoreElimination finished after 0.284 seconds
# 2024-05-01T16:43:44Z Running AliasDependencyInduction
# 2024-05-01T16:43:44Z AliasDependencyInduction finished after 0.001 seconds
# 2024-05-01T16:43:44Z Running Simplifier
# 2024-05-01T16:43:44Z Simplifier finished after 0.027 seconds
# 2024-05-01T16:43:44Z Running LICM
# 2024-05-01T16:43:44Z LICM finished after 0.012 seconds
# 2024-05-01T16:43:44Z Running Delinearization
# 2024-05-01T16:43:44Z Delinearization finished after 0.012 seconds
# 2024-05-01T16:43:44Z Running LoopFusion
# 2024-05-01T16:43:44Z LoopFusion finished after 0.062 seconds
# 2024-05-01T16:43:44Z Running SimplifySlice
# 2024-05-01T16:43:44Z SimplifySlice finished after 0.005 seconds
# 2024-05-01T16:43:44Z Running LICM
# 2024-05-01T16:43:44Z LICM finished after 0.011 seconds
# 2024-05-01T16:43:44Z Running Simplifier
# 2024-05-01T16:43:44Z Simplifier finished after 0.013 seconds
# 2024-05-01T16:43:44Z Running ValueNumbering
# 2024-05-01T16:43:44Z ValueNumbering finished after 0.012 seconds
# 2024-05-01T16:43:44Z Running LICM
# 2024-05-01T16:43:44Z LICM finished after 0.009 seconds
# 2024-05-01T16:43:44Z Running PadElimination
# 2024-05-01T16:43:44Z PadElimination finished after 0.001 seconds
# 2024-05-01T16:43:44Z Running Delinearization
# 2024-05-01T16:43:44Z Delinearization finished after 0.010 seconds
# 2024-05-01T16:43:44Z Running LoopFusion
# 2024-05-01T16:43:44Z LoopFusion finished after 0.060 seconds
# 2024-05-01T16:43:44Z Running GenericAccessSimplifier
# 2024-05-01T16:43:44Z GenericAccessSimplifier finished after 0.006 seconds
# 2024-05-01T16:43:44Z Running Simplifier
# 2024-05-01T16:43:44Z Simplifier finished after 0.014 seconds
# 2024-05-01T16:43:44Z Running LICM
# 2024-05-01T16:43:44Z LICM finished after 0.011 seconds
# 2024-05-01T16:43:44Z Running ValueNumbering
# 2024-05-01T16:43:44Z ValueNumbering finished after 0.010 seconds
# 2024-05-01T16:43:44Z Running TCTransform
# 2024-05-01T16:43:44Z TCTransform finished after 0.007 seconds
# 2024-05-01T16:43:44Z Running CommuteConcat
# 2024-05-01T16:43:44Z CommuteConcat finished after 0.006 seconds
# 2024-05-01T16:43:44Z Running RecognizeOpIdiom
# 2024-05-01T16:43:44Z RecognizeOpIdiom finished after 0.025 seconds
# 2024-05-01T16:43:44Z Running MaskPropagation
# 2024-05-01T16:43:44Z MaskPropagation finished after 0.011 seconds
# 2024-05-01T16:43:44Z Running DeadStoreElimination
# 2024-05-01T16:43:44Z DeadStoreElimination finished after 0.225 seconds
# 2024-05-01T16:43:44Z Running Recompute
# 2024-05-01T16:43:44Z Recompute finished after 0.001 seconds
# 2024-05-01T16:43:44Z Running DeadCodeElimination
# 2024-05-01T16:43:44Z DeadCodeElimination finished after 0.006 seconds
# 2024-05-01T16:43:44Z Running DoNothing
# 2024-05-01T16:43:44Z DoNothing finished after 0.000 seconds
# 2024-05-01T16:43:44Z Running MutateDataType
# 2024-05-01T16:43:44Z MutateDataType finished after 0.004 seconds
# 2024-05-01T16:43:44Z Running AutoCastTCInputs
# 2024-05-01T16:43:44Z AutoCastTCInputs finished after 0.011 seconds
# 2024-05-01T16:43:44Z Running GenericAccessSimplifier
# 2024-05-01T16:43:44Z GenericAccessSimplifier finished after 0.006 seconds
# 2024-05-01T16:43:44Z Running Simplifier
# 2024-05-01T16:43:44Z Simplifier finished after 0.014 seconds
# 2024-05-01T16:43:44Z Running AliasDependencyElimination
# 2024-05-01T16:43:44Z AliasDependencyElimination finished after 0.006 seconds
# 2024-05-01T16:43:44Z Running DelinearIndices
# 2024-05-01T16:43:45Z DelinearIndices finished after 0.023 seconds
# 2024-05-01T16:43:45Z Running Delinearization
# 2024-05-01T16:43:45Z Delinearization finished after 0.010 seconds
# 2024-05-01T16:43:45Z Running DelinearIndices
# 2024-05-01T16:43:45Z DelinearIndices finished after 0.023 seconds
# 2024-05-01T16:43:45Z Running DeadCodeElimination
# 2024-05-01T16:43:45Z DeadCodeElimination finished after 0.006 seconds
# 2024-05-01T16:43:45Z Running InferIntrinsicOnCC
# 2024-05-01T16:43:45Z InferIntrinsicOnCC finished after 0.050 seconds
# 2024-05-01T16:43:45Z Running ResolveAccessConflict
# 2024-05-01T16:43:45Z ResolveAccessConflict finished after 0.033 seconds
# 2024-05-01T16:43:45Z Running LICM
# 2024-05-01T16:43:45Z LICM finished after 0.012 seconds
# 2024-05-01T16:43:45Z Running LocalLayoutOpt
# 2024-05-01T16:43:45Z LocalLayoutOpt finished after 0.055 seconds
# 2024-05-01T16:43:45Z Running DelinearIndices
# 2024-05-01T16:43:45Z DelinearIndices finished after 0.025 seconds
# 2024-05-01T16:43:45Z Running PGLayoutTilingPipeline
# 2024-05-01T16:43:45Z Running LayoutPreprocessingAndAnalysis
# 2024-05-01T16:43:45Z Running LayoutPreprocessing
# 2024-05-01T16:43:45Z Running Delinearization
# 2024-05-01T16:43:45Z Delinearization finished after 0.011 seconds
# 2024-05-01T16:43:45Z LayoutPreprocessing finished after 0.035 seconds
# 2024-05-01T16:43:45Z Running LayoutRequirementAnalysis
# 2024-05-01T16:43:45Z LayoutRequirementAnalysis finished after 0.028 seconds
# 2024-05-01T16:43:45Z LayoutPreprocessingAndAnalysis finished after 0.073 seconds
# 2024-05-01T16:43:45Z Running PAGLayoutOpt
# 2024-05-01T16:43:45Z PAGLayoutOpt finished after 0.073 seconds
# 2024-05-01T16:43:45Z Running MaskPropagation
# 2024-05-01T16:43:45Z MaskPropagation finished after 0.014 seconds
# 2024-05-01T16:43:45Z Running CanonicalizeDAGForPGTiling
# 2024-05-01T16:43:45Z CanonicalizeDAGForPGTiling finished after 0.018 seconds
# 2024-05-01T16:43:45Z Running PGTiling
# 2024-05-01T16:43:45Z Running AGOrderingAnalysisPass
# 2024-05-01T16:43:45Z AGOrderingAnalysisPass finished after 0.093 seconds
# 2024-05-01T16:43:45Z Running CuttingAndMacroGeneration
# 2024-05-01T16:43:45Z CuttingAndMacroGeneration finished after 0.414 seconds
# 2024-05-01T16:43:45Z PGTiling finished after 0.517 seconds
# 2024-05-01T16:43:45Z Running InsertIOTransposes
# 2024-05-01T16:43:46Z InsertIOTransposes finished after 0.071 seconds
# 2024-05-01T16:43:46Z PGLayoutTilingPipeline finished after 0.799 seconds
# 2024-05-01T16:43:46Z Running TilingProfiler
# 2024-05-01T16:43:46Z TilingProfiler finished after 0.053 seconds
# 2024-05-01T16:43:46Z Running FlattenMacroLoop
# 2024-05-01T16:43:46Z FlattenMacroLoop finished after 0.081 seconds
# 2024-05-01T16:43:46Z Running InferNeuronTensor
# 2024-05-01T16:43:46Z InferNeuronTensor finished after 0.306 seconds
# 2024-05-01T16:43:46Z Running NeuronSimplifier
# 2024-05-01T16:43:46Z NeuronSimplifier finished after 0.166 seconds
# 2024-05-01T16:43:46Z Running LICM
# 2024-05-01T16:43:46Z LICM finished after 0.028 seconds
# 2024-05-01T16:43:46Z Running RewriteReplicationMatmul
# 2024-05-01T16:43:46Z RewriteReplicationMatmul finished after 0.014 seconds
# 2024-05-01T16:43:46Z Running FlattenMacroLoop
# 2024-05-01T16:43:46Z FlattenMacroLoop finished after 0.064 seconds
# 2024-05-01T16:43:46Z Running SimplifyMacroPredicates
# 2024-05-01T16:43:47Z SimplifyMacroPredicates finished after 1.035 seconds
# 2024-05-01T16:43:47Z Running DataLocalityOpt
# 2024-05-01T16:43:48Z DataLocalityOpt finished after 0.266 seconds
# 2024-05-01T16:43:48Z Running DMATilingProfiler
# 2024-05-01T16:43:48Z DMATilingProfiler finished after 0.013 seconds
# 2024-05-01T16:43:48Z Running NeuronSimplifier
# 2024-05-01T16:43:48Z NeuronSimplifier finished after 0.057 seconds
# 2024-05-01T16:43:48Z Running LegalizeSundaMacro
# 2024-05-01T16:43:48Z LegalizeSundaMacro finished after 0.029 seconds
# 2024-05-01T16:43:48Z Running NeuronSimplifier
# 2024-05-01T16:43:48Z NeuronSimplifier finished after 0.059 seconds
# 2024-05-01T16:43:48Z Running PerfectLoopNest
# 2024-05-01T16:43:48Z PerfectLoopNest finished after 0.014 seconds
# 2024-05-01T16:43:48Z Running FlattenMacroLoop
# 2024-05-01T16:43:48Z FlattenMacroLoop finished after 0.038 seconds
# 2024-05-01T16:43:48Z Running RewriteWeights
# 2024-05-01T16:43:48Z RewriteWeights finished after 0.011 seconds
# 2024-05-01T16:43:48Z Running ReshapeWeights
# 2024-05-01T16:43:48Z ReshapeWeights finished after 0.003 seconds
# 2024-05-01T16:43:48Z Running FlattenMacroLoop
# 2024-05-01T16:43:48Z FlattenMacroLoop finished after 0.031 seconds
# 2024-05-01T16:43:48Z Running SimplifyMacroPredicates
# 2024-05-01T16:43:49Z SimplifyMacroPredicates finished after 1.123 seconds
# 2024-05-01T16:43:49Z Running InferInitValue
# 2024-05-01T16:43:50Z InferInitValue finished after 0.727 seconds
# 2024-05-01T16:43:50Z Running NeuronSimplifier
# 2024-05-01T16:43:50Z NeuronSimplifier finished after 0.058 seconds
# 2024-05-01T16:43:50Z Running SimplifyTensor
# 2024-05-01T16:43:50Z SimplifyTensor finished after 0.046 seconds
# 2024-05-01T16:43:50Z Running LICM
# 2024-05-01T16:43:50Z LICM finished after 0.026 seconds
# 2024-05-01T16:43:50Z Running SundaISel
# 2024-05-01T16:43:50Z SundaISel finished after 0.260 seconds
# 2024-05-01T16:43:50Z Running PreprocessNkiKernels
# 2024-05-01T16:43:50Z PreprocessNkiKernels finished after 0.009 seconds
# 2024-05-01T16:43:50Z Running NeuronLoopInterchange
# 2024-05-01T16:43:50Z NeuronLoopInterchange finished after 0.009 seconds
# 2024-05-01T16:43:50Z Running NeuronSimplifyPredicates
# 2024-05-01T16:43:51Z NeuronSimplifyPredicates finished after 0.584 seconds
# 2024-05-01T16:43:51Z Running NeuronLoopFusion
# 2024-05-01T16:43:51Z NeuronLoopFusion finished after 0.138 seconds
# 2024-05-01T16:43:51Z Running NeuronLoopInterchange
# 2024-05-01T16:43:51Z NeuronLoopInterchange finished after 0.009 seconds
# 2024-05-01T16:43:51Z Running NeuronLICM
# 2024-05-01T16:43:51Z NeuronLICM finished after 0.049 seconds
# 2024-05-01T16:43:51Z Running FactorizeBlkDims
# 2024-05-01T16:43:51Z FactorizeBlkDims finished after 0.099 seconds
# 2024-05-01T16:43:51Z Running NeuronInstComb
# 2024-05-01T16:43:51Z NeuronInstComb finished after 0.135 seconds
# 2024-05-01T16:43:51Z Running NeuronValueNumbering
# 2024-05-01T16:43:51Z NeuronValueNumbering finished after 0.043 seconds
# 2024-05-01T16:43:51Z Running NeuronInstComb
# 2024-05-01T16:43:51Z NeuronInstComb finished after 0.023 seconds
# 2024-05-01T16:43:51Z Running VectorizeDMA
# 2024-05-01T16:43:51Z VectorizeDMA finished after 0.076 seconds
# 2024-05-01T16:43:51Z Running NeuronSimplifyPredicates
# 2024-05-01T16:43:52Z NeuronSimplifyPredicates finished after 0.446 seconds
# 2024-05-01T16:43:52Z Running LegalizePartitionReduce
# 2024-05-01T16:43:52Z LegalizePartitionReduce finished after 0.012 seconds
# 2024-05-01T16:43:52Z Running DeConcat
# 2024-05-01T16:43:52Z DeConcat finished after 0.006 seconds
# 2024-05-01T16:43:52Z Running PartialSimdFusion
# 2024-05-01T16:43:52Z PartialSimdFusion finished after 0.159 seconds
# 2024-05-01T16:43:52Z Running TritiumFusion
# 2024-05-01T16:43:52Z TritiumFusion finished after 0.146 seconds
# 2024-05-01T16:43:52Z Running CCOpFusion
# 2024-05-01T16:43:52Z CCOpFusion finished after 0.089 seconds
# 2024-05-01T16:43:52Z Running VectorizeMatMult
# 2024-05-01T16:43:52Z VectorizeMatMult finished after 0.066 seconds
# 2024-05-01T16:43:52Z Running PartialLoopFusion
# 2024-05-01T16:43:53Z PartialLoopFusion finished after 0.103 seconds
# 2024-05-01T16:43:53Z Running NeuronLICM
# 2024-05-01T16:43:53Z NeuronLICM finished after 0.020 seconds
# 2024-05-01T16:43:53Z Running LowerTranspose
# 2024-05-01T16:43:53Z LowerTranspose finished after 0.089 seconds
# 2024-05-01T16:43:53Z Running LateNeuronInstComb
# 2024-05-01T16:43:53Z LateNeuronInstComb finished after 0.109 seconds
# 2024-05-01T16:43:53Z Running SplitAccGrp
# 2024-05-01T16:43:53Z SplitAccGrp finished after 0.009 seconds
# 2024-05-01T16:43:53Z Running SpillPSum
# 2024-05-01T16:43:53Z SpillPSum finished after 0.092 seconds
# 2024-05-01T16:43:53Z Running LowerIntrinsics
# 2024-05-01T16:43:53Z LowerIntrinsics finished after 0.064 seconds
# 2024-05-01T16:43:53Z Running LegalizeType
# 2024-05-01T16:43:53Z LegalizeType finished after 0.013 seconds
# 2024-05-01T16:43:53Z Running NeuronLICM
# 2024-05-01T16:43:53Z NeuronLICM finished after 0.029 seconds
# 2024-05-01T16:43:53Z Running InferPSumTensor
# 2024-05-01T16:43:53Z InferPSumTensor finished after 0.129 seconds
# 2024-05-01T16:43:53Z Running WeightCoalescing
# 2024-05-01T16:43:53Z WeightCoalescing finished after 0.009 seconds
# 2024-05-01T16:43:53Z Running LegalizeSundaAccess
# 2024-05-01T16:43:53Z LegalizeSundaAccess finished after 0.200 seconds
# 2024-05-01T16:43:53Z Running TernaryFission
# 2024-05-01T16:43:54Z TernaryFission finished after 0.379 seconds
# 2024-05-01T16:43:54Z Running RelaxPredicates
# 2024-05-01T16:44:02Z input_dma_coalescing finished after 0.047 seconds
# 2024-05-01T16:44:02Z Running early_peephole_opts
# 2024-05-01T16:44:02Z early_peephole_opts finished after 0.010 seconds
# 2024-05-01T16:44:02Z Running pre_sched
# 2024-05-01T16:44:03Z pre_sched finished after 0.398 seconds
# 2024-05-01T16:44:03Z Running tensor_copy_elim
# 2024-05-01T16:44:03Z tensor_copy_elim finished after 0.047 seconds
# 2024-05-01T16:44:03Z Running mm_packing
# 2024-05-01T16:44:03Z mm_packing finished after 0.183 seconds
# 2024-05-01T16:44:03Z Running coloring_allocator_psum
# 2024-05-01T16:44:03Z coloring_allocator_psum finished after 0.100 seconds
# 2024-05-01T16:44:03Z Running dma_optimization_psum
# 2024-05-01T16:44:03Z dma_optimization_psum finished after 0.041 seconds
# 2024-05-01T16:44:03Z Running address_rotation_psum
# 2024-05-01T16:44:03Z address_rotation_psum finished after 0.134 seconds
# 2024-05-01T16:44:03Z Running coloring_allocator_sb
# 2024-05-01T16:44:04Z coloring_allocator_sb finished after 0.664 seconds
# 2024-05-01T16:44:04Z Running address_rotation_sb
# 2024-05-01T16:44:04Z address_rotation_sb finished after 0.052 seconds
# 2024-05-01T16:44:04Z Running dma_optimization_sb
# 2024-05-01T16:44:04Z dma_optimization_sb finished after 0.304 seconds
# 2024-05-01T16:44:04Z Running address_rotation_sb
# 2024-05-01T16:44:05Z address_rotation_sb finished after 0.551 seconds
# 2024-05-01T16:44:05Z Running coloring_allocator_dram
# 2024-05-01T16:44:07Z coloring_allocator_dram finished after 1.872 seconds
# 2024-05-01T16:44:07Z Running address_rotation_dram
# 2024-05-01T16:44:07Z address_rotation_dram finished after 0.095 seconds
# 2024-05-01T16:44:07Z Running tensorcopy_accel
# 2024-05-01T16:44:07Z tensorcopy_accel finished after 0.004 seconds
# 2024-05-01T16:44:07Z Running peephole_opts
# 2024-05-01T16:44:07Z peephole_opts finished after 0.011 seconds
# 2024-05-01T16:44:07Z Running lower_kernel
# 2024-05-01T16:44:07Z lower_kernel finished after 0.004 seconds
# 2024-05-01T16:44:07Z Running build_fdeps
# 2024-05-01T16:44:07Z build_fdeps finished after 0.146 seconds
# 2024-05-01T16:44:07Z Running remove_redundancies
# 2024-05-01T16:44:07Z remove_redundancies finished after 0.065 seconds
# 2024-05-01T16:44:07Z Running anti_dependency_analyzer
# 2024-05-01T16:44:09Z anti_dependency_analyzer finished after 1.426 seconds
# 2024-05-01T16:44:09Z Running tensor_copy_elim
# 2024-05-01T16:44:09Z tensor_copy_elim finished after 0.060 seconds
# 2024-05-01T16:44:09Z Running post_sched
# 2024-05-01T16:44:09Z post_sched finished after 0.657 seconds
# 2024-05-01T16:44:09Z Running address_rotation_sb
# 2024-05-01T16:44:10Z address_rotation_sb finished after 0.794 seconds
# 2024-05-01T16:44:10Z Running anti_dependency_analyzer
# 2024-05-01T16:44:12Z anti_dependency_analyzer finished after 1.594 seconds
# 2024-05-01T16:44:12Z Running dep_opt
# 2024-05-01T16:44:12Z dep_opt finished after 0.335 seconds
# 2024-05-01T16:44:12Z Running report_stats
# 2024-05-01T16:44:12Z report_stats finished after 0.016 seconds
# 2024-05-01T16:44:12Z Running assign_trigger_engine
# 2024-05-01T16:44:12Z assign_trigger_engine finished after 0.012 seconds
# 2024-05-01T16:44:12Z Running alloc_queues
# 2024-05-01T16:44:12Z alloc_queues finished after 0.010 seconds
# 2024-05-01T16:44:12Z mod_parallel_pass finished after 10.472 seconds
# 2024-05-01T16:44:12Z Running dep_reduction
# 2024-05-01T16:44:13Z dep_reduction finished after 0.868 seconds
# 2024-05-01T16:44:13Z Running bir_racecheck
# 2024-05-01T16:44:14Z bir_racecheck finished after 1.099 seconds
# 2024-05-01T16:44:14Z Running lower_dma
# 2024-05-01T16:44:15Z lower_dma finished after 0.334 seconds
# 2024-05-01T16:44:15Z Running coalesce_dma_blocks
# 2024-05-01T16:44:15Z coalesce_dma_blocks finished after 0.068 seconds
# 2024-05-01T16:44:15Z Running alloc_semaphores
# 2024-05-01T16:44:15Z alloc_semaphores finished after 0.064 seconds
# 2024-05-01T16:44:15Z Running expand_inst_late
# 2024-05-01T16:44:15Z expand_inst_late finished after 0.005 seconds
# 2024-05-01T16:44:15Z Running lower_sync
# 2024-05-01T16:44:15Z lower_sync finished after 0.053 seconds
# 2024-05-01T16:44:15Z Running lower_act
# 2024-05-01T16:44:15Z lower_act finished after 0.008 seconds
# 2024-05-01T16:44:15Z Running lower_dve
# 2024-05-01T16:44:15Z lower_dve finished after 0.045 seconds
# 2024-05-01T16:44:15Z Running lower_ap
# 2024-05-01T16:44:15Z lower_ap finished after 0.011 seconds
# 2024-05-01T16:44:15Z Running alloc_regs
# 2024-05-01T16:44:15Z alloc_regs finished after 0.002 seconds
# 2024-05-01T16:44:15Z Running birverifier
# 2024-05-01T16:44:15Z birverifier finished after 0.056 seconds
# 2024-05-01T16:44:15Z Running codegen
# 2024-05-01T16:44:15Z isa_gen finished after 0.174 seconds
# 2024-05-01T16:44:15Z dma_desc_gen finished after 0.281 seconds
# 2024-05-01T16:44:15Z debug_info_gen finished after 0.162 seconds
# 2024-05-01T16:44:16Z codegen finished after 0.679 seconds
# 2024-05-01T16:44:16Z Running neff_packager
# 2024-05-01T16:44:16Z neff_packager finished after 0.235 seconds
# 2024-05-01T16:44:16Z Compiler status PASS
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Exporting decoder: whisper-tiny
# Some weights of WhisperForConditionalGeneration were not initialized from the model checkpoint at openai/whisper-tiny and are newly initialized: ['proj_out.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# > initializing tensor model parallel with size 2
# > initializing pipeline model parallel with size 1
# > initializing data parallel with size 1
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# [2024-05-01 16:44:24.992: I neuronx_distributed/parallel_layers/checkpointing.py:148] `load` kwarg `model` is deprecated, please use `model_or_optimizer` instead as we are supporting to use `load` with optimizer as well
# [2024-05-01 16:44:24.992: I neuronx_distributed/parallel_layers/checkpointing.py:161] loading checkpoint from whisper-tiny.pt
# 2024-05-01 16:44:35.000333:  111565  INFO ||NEURON_CACHE||: Compile cache path: /var/tmp/neuron-compile-cache
# 2024-05-01 16:44:35.000334:  111565  INFO ||NEURON_CC_WRAPPER||: Using a cached neff at /var/tmp/neuron-compile-cache/neuronxcc-2.13.68.0+6dfecc895/MODULE_15990054738812213478+d41d8cd9/model.neff. Exiting with a successfully compiled graph.
# 2024-05-01 16:44:35.000799:  111572  INFO ||NEURON_CACHE||: Compile cache path: /var/tmp/neuron-compile-cache
# 2024-05-01 16:44:35.000800:  111572  INFO ||NEURON_CC_WRAPPER||: Using a cached neff at /var/tmp/neuron-compile-cache/neuronxcc-2.13.68.0+6dfecc895/MODULE_6664652093260358530+d41d8cd9/model.neff. Exiting with a successfully compiled graph.
# 2024-05-01 16:44:36.000001:  111578  INFO ||NEURON_CACHE||: Compile cache path: /var/tmp/neuron-compile-cache
# 2024-05-01 16:44:36.000002:  111578  INFO ||NEURON_CC_WRAPPER||: Using a cached neff at /var/tmp/neuron-compile-cache/neuronxcc-2.13.68.0+6dfecc895/MODULE_766892254041788032+d41d8cd9/model.neff. Exiting with a successfully compiled graph.
# 2024-05-01 16:44:36.000195:  111587  INFO ||NEURON_CACHE||: Compile cache path: /var/tmp/neuron-compile-cache
# 2024-05-01 16:44:36.000196:  111587  INFO ||NEURON_CC_WRAPPER||: Using a cached neff at /var/tmp/neuron-compile-cache/neuronxcc-2.13.68.0+6dfecc895/MODULE_9279805290075389978+d41d8cd9/model.neff. Exiting with a successfully compiled graph.
# 2024-05-01 16:44:36.000391:  111599  INFO ||NEURON_CACHE||: Compile cache path: /var/tmp/neuron-compile-cache
# 2024-05-01 16:44:36.000392:  111599  INFO ||NEURON_CC_WRAPPER||: Using a cached neff at /var/tmp/neuron-compile-cache/neuronxcc-2.13.68.0+6dfecc895/MODULE_5923153053738227728+d41d8cd9/model.neff. Exiting with a successfully compiled graph.
# 2024-05-01 16:44:36.000582:  111605  INFO ||NEURON_CACHE||: Compile cache path: /var/tmp/neuron-compile-cache
# 2024-05-01 16:44:36.000583:  111605  INFO ||NEURON_CC_WRAPPER||: Using a cached neff at /var/tmp/neuron-compile-cache/neuronxcc-2.13.68.0+6dfecc895/MODULE_16942971074878409330+d41d8cd9/model.neff. Exiting with a successfully compiled graph.
# 2024-05-01 16:44:36.000792:  111644  INFO ||NEURON_CACHE||: Compile cache path: /var/tmp/neuron-compile-cache
# 2024-05-01 16:44:36.000793:  111644  INFO ||NEURON_CC_WRAPPER||: Using a cached neff at /var/tmp/neuron-compile-cache/neuronxcc-2.13.68.0+6dfecc895/MODULE_6628613090798822721+d41d8cd9/model.neff. Exiting with a successfully compiled graph.
# 2024-05-01 16:44:36.000989:  111650  INFO ||NEURON_CACHE||: Compile cache path: /var/tmp/neuron-compile-cache
# 2024-05-01 16:44:36.000990:  111650  INFO ||NEURON_CC_WRAPPER||: Using a cached neff at /var/tmp/neuron-compile-cache/neuronxcc-2.13.68.0+6dfecc895/MODULE_16715834710487042195+d41d8cd9/model.neff. Exiting with a successfully compiled graph.
# 2024-05-01 16:44:37.000180:  111656  INFO ||NEURON_CACHE||: Compile cache path: /var/tmp/neuron-compile-cache
# 2024-05-01 16:44:37.000181:  111656  INFO ||NEURON_CC_WRAPPER||: Using a cached neff at /var/tmp/neuron-compile-cache/neuronxcc-2.13.68.0+6dfecc895/MODULE_6664028047681252389+d41d8cd9/model.neff. Exiting with a successfully compiled graph.
# Some weights of WhisperForConditionalGeneration were not initialized from the model checkpoint at openai/whisper-tiny and are newly initialized: ['proj_out.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 
# 2024-05-01T16:44:42Z Running DoNothing
# 2024-05-01T16:44:42Z DoNothing finished after 0.000 seconds
# 2024-05-01T16:44:42Z Running MutateDataType
# 2024-05-01T16:44:42Z MutateDataType finished after 0.005 seconds
# 2024-05-01T16:44:42Z Running AutoCastTCInputs
# 2024-05-01T16:44:42Z Running DoNothing
# 2024-05-01T16:44:42Z DoNothing finished after 0.000 seconds
# 2024-05-01T16:44:42Z Running AliasDependencyInduction
# 2024-05-01T16:44:42Z AutoCastTCInputs finished after 0.016 seconds
# 2024-05-01T16:44:42Z Running GenericAccessSimplifier
# 2024-05-01T16:44:42Z AliasDependencyInduction finished after 0.002 seconds
# 2024-05-01T16:44:42Z Running CanonicalizeIR
# 2024-05-01T16:44:42Z GenericAccessSimplifier finished after 0.008 seconds
# 2024-05-01T16:44:42Z Running Simplifier
# 2024-05-01T16:44:42Z CanonicalizeIR finished after 0.007 seconds
# 2024-05-01T16:44:42Z Running LegalizeCCOpLayout
# 2024-05-01T16:44:42Z LegalizeCCOpLayout finished after 0.007 seconds
# 2024-05-01T16:44:42Z Running ResolveComplicatePredicates
# 2024-05-01T16:44:42Z ResolveComplicatePredicates finished after 0.007 seconds
# 2024-05-01T16:44:42Z Running AffinePredicateResolution
# 2024-05-01T16:44:42Z AffinePredicateResolution finished after 0.007 seconds
# 2024-05-01T16:44:42Z Running EliminateDivs
# 2024-05-01T16:44:42Z Simplifier finished after 0.043 seconds
# 2024-05-01T16:44:42Z Running AliasDependencyElimination
# 2024-05-01T16:44:42Z EliminateDivs finished after 0.007 seconds
# 2024-05-01T16:44:42Z Running PerfectLoopNest
# 2024-05-01T16:44:42Z AliasDependencyElimination finished after 0.008 seconds
# 2024-05-01T16:44:42Z Running DelinearIndices
# 2024-05-01T16:44:42Z PerfectLoopNest finished after 0.007 seconds
# 2024-05-01T16:44:42Z Running Simplifier
# 2024-05-01T16:44:42Z DelinearIndices finished after 0.025 seconds
# 2024-05-01T16:44:42Z Running Delinearization
# 2024-05-01T16:44:42Z Simplifier finished after 0.035 seconds
# 2024-05-01T16:44:42Z Running GenericAccessSimplifier
# 2024-05-01T16:44:42Z Delinearization finished after 0.010 seconds
# 2024-05-01T16:44:42Z Running DelinearIndices
# 2024-05-01T16:44:42Z GenericAccessSimplifier finished after 0.006 seconds
# 2024-05-01T16:44:42Z Running TCTransform
# 2024-05-01T16:44:42Z TCTransform finished after 0.006 seconds
# 2024-05-01T16:44:42Z Running CommuteConcat
# 2024-05-01T16:44:42Z DelinearIndices finished after 0.024 seconds
# 2024-05-01T16:44:42Z Running DeadCodeElimination
# 2024-05-01T16:44:42Z CommuteConcat finished after 0.006 seconds
# 2024-05-01T16:44:42Z Running LowerTensorOp
# 2024-05-01T16:44:42Z DeadCodeElimination finished after 0.008 seconds
# 2024-05-01T16:44:42Z Running InferIntrinsicOnCC
# 2024-05-01T16:44:42Z LowerTensorOp finished after 0.051 seconds
# 2024-05-01T16:44:42Z Running ExpandBatchNorm
# 2024-05-01T16:44:42Z InferIntrinsicOnCC finished after 0.050 seconds
# 2024-05-01T16:44:54Z TernaryFission finished after 0.299 seconds
# 2024-05-01T16:44:54Z Running RelaxPredicates
# 2024-05-01T16:44:54Z Running mod_parallel_pass
# 2024-05-01T16:44:54Z Running rewrite_matmult_sparse
# 2024-05-01T16:44:54Z rewrite_matmult_sparse finished after 0.000 seconds
# 2024-05-01T16:44:54Z Running birverifier
# 2024-05-01T16:44:54Z birverifier finished after 0.004 seconds
# 2024-05-01T16:44:54Z Running expand_replication
# 2024-05-01T16:44:54Z expand_replication finished after 0.000 seconds
# 2024-05-01T16:44:54Z Running unroll
# 2024-05-01T16:44:54Z unroll finished after 0.015 seconds
# 2024-05-01T16:44:54Z Running psum_legalization
# 2024-05-01T16:44:54Z psum_legalization finished after 0.000 seconds
# 2024-05-01T16:44:54Z Running error_injector
# 2024-05-01T16:44:54Z error_injector finished after 0.000 seconds
# 2024-05-01T16:44:54Z Running constant_propagate
# 2024-05-01T16:44:54Z constant_propagate finished after 0.003 seconds
# 2024-05-01T16:44:54Z Running vn_splitter
# 2024-05-01T16:44:54Z vn_splitter finished after 0.001 seconds
# 2024-05-01T16:44:54Z Running lower_ac
# 2024-05-01T16:44:54Z lower_ac finished after 0.000 seconds
# 2024-05-01T16:44:54Z Running input_dma_coalescing
# 2024-05-01T16:44:54Z input_dma_coalescing finished after 0.000 seconds
# 2024-05-01T16:44:54Z Running early_peephole_opts
# 2024-05-01T16:44:54Z early_peephole_opts finished after 0.000 seconds
# 2024-05-01T16:44:54Z Running pre_sched
# 2024-05-01T16:44:54Z RelaxPredicates finished after 0.069 seconds
# 2024-05-01T16:44:54Z Running TensorInitialization
# 2024-05-01T16:44:54Z pre_sched finished after 0.017 seconds
# 2024-05-01T16:44:54Z Running tensor_copy_elim
# 2024-05-01T16:44:54Z tensor_copy_elim finished after 0.002 seconds
# 2024-05-01T16:44:54Z Running mm_packing
# 2024-05-01T16:44:54Z mm_packing finished after 0.005 seconds
# 2024-05-01T16:44:54Z Running coloring_allocator_psum
# 2024-05-01T16:44:54Z coloring_allocator_psum finished after 0.003 seconds
# 2024-05-01T16:44:54Z Running dma_optimization_psum
# 2024-05-01T16:44:54Z dma_optimization_psum finished after 0.001 seconds
# 2024-05-01T16:44:54Z Running address_rotation_psum
# 2024-05-01T16:44:54Z address_rotation_psum finished after 0.003 seconds
# 2024-05-01T16:44:54Z Running coloring_allocator_sb
# 2024-05-01T16:44:54Z coloring_allocator_sb finished after 0.005 seconds
# 2024-05-01T16:44:54Z Running address_rotation_sb
# 2024-05-01T16:44:54Z address_rotation_sb finished after 0.001 seconds
# 2024-05-01T16:44:54Z Running dma_optimization_sb
# 2024-05-01T16:44:54Z dma_optimization_sb finished after 0.007 seconds
# 2024-05-01T16:44:54Z Running address_rotation_sb
# 2024-05-01T16:44:54Z address_rotation_sb finished after 0.009 seconds
# 2024-05-01T16:44:54Z Running coloring_allocator_dram
# 2024-05-01T16:44:54Z coloring_allocator_dram finished after 0.001 seconds
# 2024-05-01T16:44:54Z Running address_rotation_dram
# 2024-05-01T16:44:54Z address_rotation_dram finished after 0.001 seconds
# 2024-05-01T16:44:54Z Running tensorcopy_accel
# 2024-05-01T16:44:54Z tensorcopy_accel finished after 0.000 seconds
# 2024-05-01T16:44:54Z Running peephole_opts
# 2024-05-01T16:44:54Z peephole_opts finished after 0.000 seconds
# 2024-05-01T16:44:54Z Running lower_kernel
# 2024-05-01T16:44:54Z lower_kernel finished after 0.000 seconds
# 2024-05-01T16:44:54Z Running build_fdeps
# 2024-05-01T16:44:54Z build_fdeps finished after 0.004 seconds
# 2024-05-01T16:44:54Z Running remove_redundancies
# 2024-05-01T16:44:54Z remove_redundancies finished after 0.000 seconds
# 2024-05-01T16:44:54Z Running anti_dependency_analyzer
# 2024-05-01T16:44:54Z anti_dependency_analyzer finished after 0.007 seconds
# 2024-05-01T16:44:54Z Running tensor_copy_elim
# 2024-05-01T16:44:54Z tensor_copy_elim finished after 0.002 seconds
# 2024-05-01T16:44:54Z Running post_sched
# 2024-05-01T16:44:54Z post_sched finished after 0.033 seconds
# 2024-05-01T16:44:54Z Running address_rotation_sb
# 2024-05-01T16:44:54Z address_rotation_sb finished after 0.021 seconds
# 2024-05-01T16:44:54Z Running anti_dependency_analyzer
# 2024-05-01T16:44:54Z anti_dependency_analyzer finished after 0.008 seconds
# 2024-05-01T16:44:54Z Running dep_opt
# 2024-05-01T16:44:54Z dep_opt finished after 0.005 seconds
# 2024-05-01T16:44:54Z Running report_stats
# 2024-05-01T16:44:54Z report_stats finished after 0.000 seconds
# 2024-05-01T16:44:54Z Running assign_trigger_engine
# 2024-05-01T16:44:54Z assign_trigger_engine finished after 0.000 seconds
# 2024-05-01T16:44:54Z Running alloc_queues
# 2024-05-01T16:44:54Z alloc_queues finished after 0.000 seconds
# 2024-05-01T16:44:54Z mod_parallel_pass finished after 0.164 seconds
# 2024-05-01T16:44:54Z Running dep_reduction
# 2024-05-01T16:44:54Z dep_reduction finished after 0.014 seconds
# 2024-05-01T16:44:54Z Running bir_racecheck
# 2024-05-01T16:44:54Z bir_racecheck finished after 0.011 seconds
# 2024-05-01T16:44:54Z Running lower_dma
# 2024-05-01T16:44:54Z lower_dma finished after 0.001 seconds
# 2024-05-01T16:44:54Z Running coalesce_dma_blocks
# 2024-05-01T16:44:54Z coalesce_dma_blocks finished after 0.000 seconds
# 2024-05-01T16:44:54Z Running alloc_semaphores
# 2024-05-01T16:44:54Z alloc_semaphores finished after 0.001 seconds
# 2024-05-01T16:44:54Z Running expand_inst_late
# 2024-05-01T16:44:54Z expand_inst_late finished after 0.000 seconds
# 2024-05-01T16:44:54Z Running lower_sync
# 2024-05-01T16:44:54Z lower_sync finished after 0.000 seconds
# 2024-05-01T16:44:54Z Running lower_act
# 2024-05-01T16:44:54Z lower_act finished after 0.001 seconds
# 2024-05-01T16:44:54Z Running lower_dve
# 2024-05-01T16:44:54Z lower_dve finished after 0.003 seconds
# 2024-05-01T16:44:54Z Running lower_ap
# 2024-05-01T16:44:54Z lower_ap finished after 0.000 seconds
# 2024-05-01T16:44:54Z Running alloc_regs
# 2024-05-01T16:44:54Z alloc_regs finished after 0.000 seconds
# 2024-05-01T16:44:54Z Running birverifier
# 2024-05-01T16:44:54Z birverifier finished after 0.002 seconds
# 2024-05-01T16:44:54Z Running codegen
# 2024-05-01T16:44:54Z isa_gen finished after 0.009 seconds
# 2024-05-01T16:44:54Z dma_desc_gen finished after 0.001 seconds
# 2024-05-01T16:44:54Z debug_info_gen finished after 0.003 seconds
# 2024-05-01T16:44:54Z codegen finished after 0.015 seconds
# 2024-05-01T16:44:54Z Running neff_packager
# 2024-05-01T16:44:54Z TensorInitialization finished after 0.261 seconds
# 2024-05-01T16:44:54Z Running NeuronSimplifyPredicates
# 2024-05-01T16:44:54Z NeuronSimplifyPredicates finished after 0.430 seconds
# 2024-05-01T16:44:54Z Running ExpandISAMacro
# 2024-05-01T16:44:54Z ExpandISAMacro finished after 0.015 seconds
# 2024-05-01T16:44:54Z Running SimplifyNeuronTensor
# 2024-05-01T16:44:55Z SimplifyNeuronTensor finished after 0.078 seconds
# 2024-05-01T16:44:55Z Running DMALocalityOpt
# 2024-05-01T16:44:55Z DMALocalityOpt finished after 0.005 seconds
# 2024-05-01T16:44:55Z Running DataStreaming
# 2024-05-01T16:44:55Z DataStreaming finished after 0.022 seconds
# 2024-05-01T16:44:55Z Running SFKVectorizer
# 2024-05-01T16:44:55Z SFKVectorizer finished after 0.786 seconds
# 2024-05-01T16:44:55Z Running LateLegalizeInst
# 2024-05-01T16:44:55Z LateLegalizeInst finished after 0.011 seconds
# 2024-05-01T16:44:55Z Running CoalesceCCOp
# 2024-05-01T16:44:55Z CoalesceCCOp finished after 0.018 seconds
# 2024-05-01T16:44:55Z Running SimpleAllReduceTiling
# 2024-05-01T16:44:55Z SimpleAllReduceTiling finished after 0.011 seconds
# 2024-05-01T16:44:55Z Running StaticProfiler
# 2024-05-01T16:44:55Z StaticProfiler finished after 0.027 seconds
# 2024-05-01T16:44:55Z Running SplitAPUnionSets
# 2024-05-01T16:44:56Z SplitAPUnionSets finished after 0.488 seconds
# 2024-05-01T16:44:56Z Running DumpGraphAndMetadata
# 2024-05-01T16:44:56Z DumpGraphAndMetadata finished after 0.032 seconds
# 2024-05-01T16:44:56Z Running BirCodeGenLoop
# 2024-05-01T16:44:56Z BirCodeGenLoop finished after 0.360 seconds
# 2024-05-01T16:44:57Z neff_packager finished after 2.850 seconds
# 2024-05-01T16:44:57Z Compiler status PASS
# 2024-05-01T16:44:57Z Running mod_parallel_pass
# 2024-05-01T16:44:57Z Running rewrite_matmult_sparse
# 2024-05-01T16:44:57Z rewrite_matmult_sparse finished after 0.000 seconds
# 2024-05-01T16:44:57Z Running birverifier
# 2024-05-01T16:44:57Z birverifier finished after 0.004 seconds
# 2024-05-01T16:44:57Z Running expand_replication
# 2024-05-01T16:44:57Z expand_replication finished after 0.000 seconds
# 2024-05-01T16:44:57Z Running unroll
# 2024-05-01T16:44:57Z unroll finished after 0.014 seconds
# 2024-05-01T16:44:57Z Running psum_legalization
# 2024-05-01T16:44:57Z psum_legalization finished after 0.000 seconds
# 2024-05-01T16:44:57Z Running error_injector
# 2024-05-01T16:44:57Z error_injector finished after 0.000 seconds
# 2024-05-01T16:44:57Z Running constant_propagate
# 2024-05-01T16:44:57Z constant_propagate finished after 0.002 seconds
# 2024-05-01T16:44:57Z Running vn_splitter
# 2024-05-01T16:44:57Z vn_splitter finished after 0.001 seconds
# 2024-05-01T16:44:57Z Running lower_ac
# 2024-05-01T16:44:57Z lower_ac finished after 0.000 seconds
# 2024-05-01T16:44:57Z Running input_dma_coalescing
# 2024-05-01T16:44:57Z input_dma_coalescing finished after 0.000 seconds
# 2024-05-01T16:44:57Z Running early_peephole_opts
# 2024-05-01T16:44:57Z early_peephole_opts finished after 0.000 seconds
# 2024-05-01T16:44:57Z Running pre_sched
# 2024-05-01T16:44:57Z pre_sched finished after 0.016 seconds
# 2024-05-01T16:44:57Z Running tensor_copy_elim
# 2024-05-01T16:44:57Z tensor_copy_elim finished after 0.002 seconds
# 2024-05-01T16:44:57Z Running mm_packing
# 2024-05-01T16:44:57Z mm_packing finished after 0.005 seconds
# 2024-05-01T16:44:57Z Running coloring_allocator_psum
# 2024-05-01T16:44:57Z coloring_allocator_psum finished after 0.003 seconds
# 2024-05-01T16:44:57Z Running dma_optimization_psum
# 2024-05-01T16:44:57Z dma_optimization_psum finished after 0.001 seconds
# 2024-05-01T16:44:57Z Running address_rotation_psum
# 2024-05-01T16:44:57Z address_rotation_psum finished after 0.003 seconds
# 2024-05-01T16:44:57Z Running coloring_allocator_sb
# 2024-05-01T16:44:57Z coloring_allocator_sb finished after 0.005 seconds
# 2024-05-01T16:44:57Z Running address_rotation_sb
# 2024-05-01T16:44:57Z address_rotation_sb finished after 0.001 seconds
# 2024-05-01T16:44:57Z Running dma_optimization_sb
# 2024-05-01T16:44:57Z dma_optimization_sb finished after 0.007 seconds
# 2024-05-01T16:44:57Z Running address_rotation_sb
# 2024-05-01T16:44:57Z address_rotation_sb finished after 0.009 seconds
# 2024-05-01T16:44:57Z Running coloring_allocator_dram
# 2024-05-01T16:44:57Z coloring_allocator_dram finished after 0.001 seconds
# 2024-05-01T16:44:57Z Running address_rotation_dram
# 2024-05-01T16:44:57Z address_rotation_dram finished after 0.001 seconds
# 2024-05-01T16:44:57Z Running tensorcopy_accel
# 2024-05-01T16:44:57Z tensorcopy_accel finished after 0.000 seconds
# 2024-05-01T16:44:57Z Running peephole_opts
# 2024-05-01T16:44:57Z peephole_opts finished after 0.000 seconds
# 2024-05-01T16:44:57Z Running lower_kernel
# 2024-05-01T16:44:57Z lower_kernel finished after 0.000 seconds
# 2024-05-01T16:44:57Z Running build_fdeps
# 2024-05-01T16:44:57Z build_fdeps finished after 0.004 seconds
# 2024-05-01T16:44:57Z Running remove_redundancies
# 2024-05-01T16:44:57Z remove_redundancies finished after 0.000 seconds
# 2024-05-01T16:44:57Z Running anti_dependency_analyzer
# 2024-05-01T16:44:57Z anti_dependency_analyzer finished after 0.005 seconds
# 2024-05-01T16:44:57Z Running tensor_copy_elim
# 2024-05-01T16:44:57Z tensor_copy_elim finished after 0.002 seconds
# 2024-05-01T16:44:57Z Running post_sched
# 2024-05-01T16:44:57Z post_sched finished after 0.031 seconds
# 2024-05-01T16:44:57Z Running address_rotation_sb
# 2024-05-01T16:44:57Z address_rotation_sb finished after 0.020 seconds
# 2024-05-01T16:44:57Z Running anti_dependency_analyzer
# 2024-05-01T16:44:57Z anti_dependency_analyzer finished after 0.006 seconds
# 2024-05-01T16:44:57Z Running dep_opt
# 2024-05-01T16:44:57Z dep_opt finished after 0.009 seconds
# 2024-05-01T16:44:57Z Running report_stats
# 2024-05-01T16:44:57Z report_stats finished after 0.000 seconds
# 2024-05-01T16:44:57Z Running assign_trigger_engine
# 2024-05-01T16:44:57Z assign_trigger_engine finished after 0.000 seconds
# 2024-05-01T16:44:57Z Running alloc_queues
# 2024-05-01T16:44:57Z alloc_queues finished after 0.000 seconds
# 2024-05-01T16:44:57Z mod_parallel_pass finished after 0.159 seconds
# 2024-05-01T16:44:57Z Running dep_reduction
# 2024-05-01T16:44:57Z dep_reduction finished after 0.013 seconds
# 2024-05-01T16:44:57Z Running bir_racecheck
# 2024-05-01T16:44:57Z bir_racecheck finished after 0.011 seconds
# 2024-05-01T16:44:57Z Running lower_dma
# 2024-05-01T16:44:57Z lower_dma finished after 0.001 seconds
# 2024-05-01T16:44:57Z Running coalesce_dma_blocks
# 2024-05-01T16:44:57Z coalesce_dma_blocks finished after 0.001 seconds
# 2024-05-01T16:44:57Z Running alloc_semaphores
# 2024-05-01T16:44:57Z alloc_semaphores finished after 0.001 seconds
# 2024-05-01T16:44:57Z Running expand_inst_late
# 2024-05-01T16:44:57Z expand_inst_late finished after 0.000 seconds
# 2024-05-01T16:44:57Z Running lower_sync
# 2024-05-01T16:44:57Z lower_sync finished after 0.000 seconds
# 2024-05-01T16:44:57Z Running lower_act
# 2024-05-01T16:44:57Z lower_act finished after 0.001 seconds
# 2024-05-01T16:44:57Z Running lower_dve
# 2024-05-01T16:44:57Z lower_dve finished after 0.003 seconds
# 2024-05-01T16:44:57Z Running lower_ap
# 2024-05-01T16:44:57Z lower_ap finished after 0.000 seconds
# 2024-05-01T16:44:57Z Running alloc_regs
# 2024-05-01T16:44:57Z alloc_regs finished after 0.000 seconds
# 2024-05-01T16:44:57Z Running birverifier
# 2024-05-01T16:44:57Z birverifier finished after 0.002 seconds
# 2024-05-01T16:44:57Z Running codegen
# 2024-05-01T16:44:57Z isa_gen finished after 0.009 seconds
# 2024-05-01T16:44:57Z dma_desc_gen finished after 0.001 seconds
# 2024-05-01T16:44:57Z debug_info_gen finished after 0.003 seconds
# 2024-05-01T16:44:57Z codegen finished after 0.014 seconds
# 2024-05-01T16:44:57Z Running neff_packager
# 2024-05-01T16:45:00Z neff_packager finished after 2.886 seconds
# 2024-05-01T16:45:00Z Compiler status PASS
# Heads pad: 0
# TP degree: 2
# Heads pad: 0
# TP degree: 2

# %%
import os
import types
import torch
import neuronx_distributed
from datasets import load_dataset
from transformers import WhisperProcessor, WhisperForConditionalGeneration

tp_degree=2
suffix="tiny"
#suffix="large-v3"
model_id=f"openai/whisper-{suffix}"

processor = WhisperProcessor.from_pretrained(model_id)
model = WhisperForConditionalGeneration.from_pretrained(model_id, torchscript=True)
cpu_model = WhisperForConditionalGeneration.from_pretrained(model_id, torchscript=True)

dataset = load_dataset("hf-internal-testing/librispeech_asr_dummy", "clean", split="validation")
sample = dataset[3]["audio"]
input_features = processor(sample["array"], sampling_rate=sample["sampling_rate"], return_tensors="pt").input_features

model.model.decoder.forward_neuron = neuronx_distributed.trace.parallel_model_load(f"tp_model_dec_{suffix}_{tp_degree}")

max_dec_len = 64
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Some weights of WhisperForConditionalGeneration were not initialized from the model checkpoint at openai/whisper-tiny and are newly initialized: ['proj_out.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of WhisperForConditionalGeneration were not initialized from the model checkpoint at openai/whisper-tiny and are newly initialized: ['proj_out.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /opt/conda/lib/python3.10/site-packages/datasets/load.py:1461: FutureWarning: The repository for hf-internal-testing/librispeech_asr_dummy contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hf-internal-testing/librispeech_asr_dummy
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(

# %%
import torch
import time
import torch.nn.functional as F
from transformers.modeling_outputs import BaseModelOutputWithPastAndCrossAttentions

def enc_f(self, input_features, attention_mask, **kwargs):
    if hasattr(self, 'forward_neuron'):
        return self.forward_neuron(input_features, attention_mask)
    else:
        return self.forward_(input_features, attention_mask, return_dict=False)

if not hasattr(model.model.encoder, 'forward_'): model.model.encoder.forward_ = model.model.encoder.forward
model.model.encoder.forward = types.MethodType(enc_f, model.model.encoder)

def dec_f(self, input_ids, attention_mask=None, encoder_hidden_states=None, **kwargs):    
    t=time.time()
    out = None        
    if not attention_mask is None and encoder_hidden_states is None:
        ## I know, this is a quick-n-dirty workaround to align the input parameters for NeuronSDK tracer
        encoder_hidden_states, attention_mask = attention_mask,encoder_hidden_states
    inp = [input_ids, encoder_hidden_states]
    # pad the input to max_dec_len
    pad_size = torch.as_tensor(self.max_length - inp[0].shape[1])
    inp[0] = F.pad(inp[0], (0, pad_size), "constant", processor.tokenizer.pad_token_id)
    if hasattr(self, 'forward_neuron'):
        out = self.forward_neuron(*inp)
    else:        
        out = self.forward_(input_ids=inp[0], encoder_hidden_states=inp[1], return_dict=False, use_cache=False)[0]
    print(f"Elapsed encoder forward: {time.time()-t}")
    # unpad the output
    last_hidden_state = out[:, :input_ids.shape[1], :]
    return BaseModelOutputWithPastAndCrossAttentions(last_hidden_state=last_hidden_state)
if not hasattr(model.model.decoder, 'forward_'): model.model.decoder.forward_ = model.model.decoder.forward
model.model.decoder.forward = types.MethodType(dec_f, model.model.decoder)
model.model.decoder.max_length = max_dec_len

# %% [markdown]
# ## Only decoder running on inf2

# %%
# Load a sample
import time
t=time.time()
y1 = model.generate(input_features)
print(f"Elapsed time: {time.time()-t}")
y2 = cpu_model.generate(input_features)
y1,y2
# Out:
# Elapsed encoder forward: 0.0016117095947265625
# Elapsed encoder forward: 0.0013756752014160156
# Elapsed encoder forward: 0.0013403892517089844
# Elapsed encoder forward: 0.0012969970703125
# Elapsed encoder forward: 0.0014400482177734375
# Elapsed encoder forward: 0.001407623291015625
# Elapsed encoder forward: 0.0013933181762695312
# Elapsed encoder forward: 0.0013897418975830078
# Elapsed encoder forward: 0.0013837814331054688
# Elapsed encoder forward: 0.0013625621795654297
# Elapsed encoder forward: 0.0013911724090576172
# Elapsed encoder forward: 0.0013849735260009766
# Elapsed encoder forward: 0.0013873577117919922
# Elapsed encoder forward: 0.0013608932495117188
# Elapsed encoder forward: 0.0013782978057861328
# Elapsed encoder forward: 0.0013666152954101562
# Elapsed encoder forward: 0.001371145248413086
# Elapsed encoder forward: 0.0013751983642578125
# Elapsed encoder forward: 0.0013742446899414062
# Elapsed encoder forward: 0.001374959945678711
# Elapsed encoder forward: 0.0013704299926757812
# Elapsed encoder forward: 0.0013995170593261719
# Elapsed encoder forward: 0.0013725757598876953
# Elapsed encoder forward: 0.0013763904571533203
# Elapsed encoder forward: 0.0013852119445800781
# Elapsed encoder forward: 0.0013837814331054688
# Elapsed encoder forward: 0.0015802383422851562
# Elapsed encoder forward: 0.0014147758483886719
# Elapsed encoder forward: 0.0013689994812011719
# Elapsed encoder forward: 0.0014052391052246094
# Elapsed encoder forward: 0.0014023780822753906
# Elapsed encoder forward: 0.0013854503631591797
# Elapsed encoder forward: 0.001386880874633789
# Elapsed time: 0.2935810089111328
# (tensor([[50258, 50259, 50359, 50363,   634,   575, 12525, 22618,  1968,  6144,
#           35617, 20084,  1756,   311,   589,   307,   534, 10281,   934,   439,
#             293,   393,  4411,   294,   309,   457,   707,   295, 26916,   286,
#             392,  6628,    13, 50257]]),
#  tensor([[50258, 50259, 50359, 50363,   634,   575, 12525, 22618,  1968,  6144,
#           35617, 20084,  1756,   311,   589,   307,   534, 10281,   934,   439,
#             293,   393,  4411,   294,   309,   457,   707,   295, 26916,   286,
#             392,  6628,    13, 50257]]))

# %%
y1.shape,y2.shape
# Out:
# (torch.Size([1, 34]), torch.Size([1, 34]))

# %%
processor.batch_decode(y1, skip_special_tokens=True)
# Out:
# [" He has grave doubts whether Sir Frederick Layton's work is really Greek after all and can discover in it but little of Rocky Ithaca."]

# %% [markdown]
# ## Now both encoder and decoder on inf2

# %%
model.model.encoder.forward_neuron = neuronx_distributed.trace.parallel_model_load(f"tp_model_enc_{suffix}_{tp_degree}")

# %%
# Load a sample
import time
t=time.time()
y1 = model.generate(input_features)
print(f"Elapsed time: {time.time()-t}")
y2 = cpu_model.generate(input_features)
y1,y2
# Out:
# Elapsed encoder forward: 0.003704547882080078
# Elapsed encoder forward: 0.0015168190002441406
# Elapsed encoder forward: 0.0015499591827392578
# Elapsed encoder forward: 0.0013225078582763672
# Elapsed encoder forward: 0.0014243125915527344
# Elapsed time: 1.6213769912719727
# (tensor([[50258, 50259, 50359, 50363,  2411, 50257]]),
#  tensor([[50258, 50259, 50359, 50363,   634,   575, 12525, 22618,  1968,  6144,
#           35617, 20084,  1756,   311,   589,   307,   534, 10281,   934,   439,
#             293,   393,  4411,   294,   309,   457,   707,   295, 26916,   286,
#             392,  6628,    13, 50257]]))
